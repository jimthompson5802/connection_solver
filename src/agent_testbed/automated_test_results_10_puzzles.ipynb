# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# pandas display width 100
pd.set_option('display.width', 100)

# %%
df_list = [
    "../../results/automated_test_1_bedrock_haiku_1_results.pkl",
    "../../results/automated_test_1_bedrock_haiku_2_results.pkl",
    "../../results/automated_test_1_bedrock_haiku_3_results.pkl",
    "../../results/automated_test_1_bedrock_haiku_4_results.pkl",
    "../../results/automated_test_1_bedrock_hybrid_1_results.pkl",
    "../../results/automated_test_1_bedrock_hybrid_2_results.pkl",
    "../../results/automated_test_1_bedrock_hybrid_3_results.pkl",
    "../../results/automated_test_1_bedrock_hybrid_4_results.pkl",
    "../../results/automated_test_1_bedrock_sonnet_results.pkl",
    "../../results/automated_test_1_results.pkl",
    "../../results/automated_test_1_bedrock_mistralai7b_1_results.pkl",
    "../../results/automated_test_1_bedrock_mistralai7b_2_results.pkl",
    "../../results/automated_test_1_bedrock_mistralai7b_3_results.pkl",
    "../../results/automated_test_1_bedrock_mistralai7b_4_results.pkl",
]


for df_path in df_list:
    df = pd.read_pickle(df_path)
    print(df_path)
    print(df)
    print()
# Out:
# ../../results/automated_test_1_bedrock_haiku_1_results.pkl
#    solved_puzzle  number_found                                       groups_found
# 0           True             4  [[charm, hex, magic, spell], [instrument, pawn...
# 1          False             0                                                 []
# 2          False             1                   [[pares, peels, shells, shucks]]
# 3          False             1                   [[exploit, leverage, milk, use]]
# 4          False             1                       [[drain, duct, pipe, sewer]]
# 5          False             1                [[first, initial, maiden, premier]]
# 6           True             4  [[lay, place, put, set], [griddle, kettle, pan...
# 7          False             1                       [[say, voice, vote, choice]]
# 8          False             0                                                 []
# 9          False             2  [[direct, guide, lead, steer], [chow, eats, fa...
#
# ...
