# %%
import pickle
import json
import os

# %%
with open("/openai/api_key.json") as f:
    config = json.load(f)


os.environ["OPENAI_API_KEY"] = config["key"]

# %%
with open('vocabulary.pkl', 'rb') as file:
    vocabulary = pickle.load(file)

# %%
# print the vocabulary
for word, definitions in vocabulary.items():
    print(f"\n\n{word}:")
    for definition in definitions:
        print(definition)
# Out:
# uphold:
# The judge promised to uphold the law in this matter without bias.
# As citizens, we must uphold the values of honesty and integrity.
# The community came together to uphold traditions that had been passed down for generations.
#
#
# discard:
# She decided to discard the old magazines that were cluttering her living room.
# The player had to discard two cards before beginning his turn.
# After the update, the software will automatically discard outdated files.
# The artist decided to discard the initial sketches and start afresh with her painting.
# In his efforts to minimize waste, he avoids discarding perfectly usable materials.
# The committee reviewed the proposal and voted to discard it due to its lack of feasibility.
# The cook instructed her assistants to discard any ingredients that were not fresh.
# Once the proposal was proven ineffective, it was promptly discarded.
#
#
# honor:
# She received an award in honor of her outstanding service to the community.
# We must honor our commitments if we want to build trust.
# There is a certain honor in admitting one's mistakes and learning from them.
# He is an honorable person who always puts others before himself.
# The city held a ceremony to honor the veterans.
# It's an honor to be invited to speak at the conference.
# They named the new library wing in his honor.
# The soldiers acted with honor during the mission.
#
#
# energy:
# The child's energy was infectious as he played tirelessly in the park.
# Solar panels are designed to convert sunlight into usable energy.
# The CEO was impressed by the energy of the presentation.
# He felt a sudden surge of energy after drinking a cup of coffee.
# The dancer moved with an incredible energy that captivated the audience.
# Wind energy is a sustainable alternative to fossil fuels.
# Her positive energy lifted the spirits of everyone around her.
# In physics class, we learned about kinetic and potential energy.
#
#
# state:
# The state of the room was chaotic after the party.
# The Prime Minister addressed the nation in a state of emergency.
# He was in a relaxed state after meditation.
# Maine became a state in 1820.
# Science class focused on the three states of matter: solid, liquid, and gas.
# She forgot to state her name during the introduction.
# It is important to state your feelings clearly in a relationship.
# The event will take place at the State Fairgrounds.
# The governor spoke about state policies at the meeting.
# You should state the facts plainly when asked.
# His agitated state prevented him from making a rational decision.
# The letter was stamped with the state coat of arms.
#
#
# play:
# The children went outside to play in the garden.
# He plays the guitar with great skill.
# They attended a play at the local theater last night.
# She loved to play the role of Juliet in the school production.
# He observed the play of light on the water.
# Try to play fair and follow the rules during the match.
# The coach planned a strategic play to confuse the opponents.
# She hoped the weather would play a favorable role during the picnic.
# In business, he was always ahead in the play of market trends.
# They couldn't help but play around and make jokes during the meeting.
#
#
# justice:
# The court delivered justice by sentencing the guilty party to prison.
# She sought justice for her stolen property through legal means.
# He believes that justice should be served for all, regardless of status.
# In her role as a judge, she is committed to upholding justice.
#
#
# labor:
# The labor involved in building the new bridge took over a year to complete.
# Many people labor tirelessly to ensure their families are well supported.
# The labor pains indicated that the baby was on its way.
# Students often find it beneficial to labor over difficult problems to better understand them.
# The country's economy greatly depends on both manual labor and technological innovation.
# She considered starting her own business due to her dissatisfaction with the labor conditions at her current job.
#
#
# pass:
# Please pass the salt when you're done using it.
# After studying hard, she managed to pass the final exam with flying colors.
# The hiking trail is tough but offers a breathtaking view when you reach the high mountain pass.
# The move was bold, but he decided to pass on the investment opportunity as it seemed too risky.
# During the game, he executed a perfect pass to his teammate, leading to a score.
# As time unraveled, many traditions began to pass into oblivion.
# She anxiously awaited the result, believing she might fail but hoping to pass.
# At the comedy show, the host took a pass at humorously addressing the current political climate.
# He used his old student ID to get a pass for free entry to the museum.
# During the banquet, the servers began to pass around hors d'oeuvres to the guests.
#
#
# fulfill:
# She always strives to fulfill her potential in her career.
# He agreed to fulfill the contract terms by the end of the month.
# Karen felt an urge to fulfill her promise to her grandmother.
# The library aims to fulfill the needs of every reader.
#
#
# draw:
# She decided to draw a picture of the mountains on a sunny day.
# The game ended in a draw, so both teams went home satisfied.
# The artist had a natural ability to draw people into his exhibitions with his captivating pieces.
# He will draw his sword when the enemy approaches.
# She practiced her poker face to avoid giving any tells during the draw.
# Financially savvy individuals tend to draw a budget to manage their expenses effectively.
# The company decided to draw a winner from the raffle tickets.
#
#
# keep:
# She decided to keep the old letters in a safe box.
# He had to keep up with the fast pace of the race.
# The keep of the ancient castle was still standing after all these years.
#
#
# blanket:
# She pulled the blanket over her shoulders as the night grew colder.
# The new policy acts as a blanket to cover all areas of the company's operations.
# Snow blanketed the town, turning the streets into a winter wonderland.
# While hiking, a thick fog blanketed the mountain, making it difficult to see.
# The manager introduced a blanket ban on using mobile phones during meetings.
#
#
# sham:
# The entire meeting was nothing but a sham to keep us occupied.
# She realized that the show of concern was just a sham and didn’t mean anything.
# The team tried to sham their way through the presentation without doing any actual research.
# His apology was sham and everyone could see through it.
# She attended a sham marriage for the purposes of obtaining citizenship.
#
#
# sheet:
# I wrapped myself in a warm sheet to stay cozy on the chilly night.
# The rain began to fall in a sheet, drenching everything in sight.
# He planned to sheet the roof with metal to ensure durability.
# We will sheet the entire wall with plywood for a smooth finish.
#
#
# throw:
# Please throw the ball to me so we can play catch.
# He decided to throw a party for his birthday this year.
# The potter was taught to throw a bowl on the wheel with clay.
# She made a quick fix to the outfit by adding a colorful throw over her shoulders.
# A sudden throw of responsibility landed on his shoulders when he was promoted.

# %%
from openai import OpenAI

client = OpenAI()

# Function to get embedding for a sentence
def get_embedding(sentence):
    response = client.embeddings.create(
        input=[sentence],
        model="text-embedding-3-small"
    )
    return response.data[0].embedding

# Create a dictionary to store embeddings for each word and its definitions
embeddings = {}

for word, definitions in vocabulary.items():
    embeddings[word] = [get_embedding(definition) for definition in definitions]

# Print the embeddings for the word 'throw'
print(embeddings['throw'])
# Out:
# [[0.014391734264791012, -0.016400624066591263, -0.046172596514225006, -0.016549430787563324, 0.004017781000584364, -0.035607319325208664, -0.00011667043872876093, -0.01722969114780426, -0.0007101534283719957, 0.015582188032567501, -0.04825589060783386, 0.022129682824015617, -0.00327109033241868, 0.01535897795110941, 0.002428737934678793, -0.016762012615799904, 0.029973922297358513, -0.02974008396267891, 0.03530970588326454, 0.026976529508829117, 0.021895844489336014, 0.048553504049777985, -0.0069513991475105286, -0.01849454827606678, 0.042643751949071884, -0.02988889068365097, 0.00904000736773014, 0.011649439111351967, 0.04464201256632805, 0.0046688104048371315, -0.031249407678842545,