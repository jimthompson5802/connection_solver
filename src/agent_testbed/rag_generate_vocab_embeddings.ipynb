# %%
import json
import os
import pickle

import pandas as pd
import numpy as np

from rag_tools import generate_vocabulary, generate_embeddings

# %%
with open("/openai/api_key.json") as f:
    config = json.load(f)


os.environ["OPENAI_API_KEY"] = config["key"]

# %%
pickle_fp = "word_list4.pkl"
words = ["rumble", "table", "pony", "sift", "roll", "bun", "tree", "twist", "salad", "clap", "comb", "peal", "dig", "braid", "root", "book"]

vocabulary = generate_vocabulary(words)

# for word, definitions in vocabulary.items():
#     print(f"\n\n{word}:")
#     for definition in definitions:
#         print(definition)

# Convert dictionary to DataFrame
rows = []
for word, definitions in vocabulary.items():
    for definition in definitions:
        rows.append({'word': word, 'definition': definition})

df = pd.DataFrame(rows)

# Generate embeddings
embeddings = generate_embeddings(df["definition"].tolist())
df["embedding"] = [np.array(v) for v in np.array(embeddings).tolist()]

# save the dataframe as a pickle file
df.to_pickle(pickle_fp)

df
# Out:
#        word                                         definition  \
# 0    rumble  noun: A deep, resonant sound typically associa...
# 1    rumble  noun: A street fight, particularly amongst gangs.
# 2    rumble   verb: To make a continuous deep, resonant sound.
# 3    rumble  verb: To move with a resonant, rolling sound, ...
# 4    rumble  verb: To discover or expose something, often u...
# ..      ...                                                ...
# 113    book  verb: To arrange for someone to have a seat on...
# 114    book             verb: To engage or reserve in advance.
# 115    book  verb: To record charges against (a person) on ...
# 116    book  adjective: Being or related to a publication, ...
# 117    book  idiom: Close the books - To bring to an end; t...
#
#                                              embedding
# 0    [-0.006525901146233082, -0.00801665149629116, ...
# 1    [-0.02613157406449318, -0.006333488505333662, ...
# 2    [0.0348958894610405, -0.01895660161972046, -0....
# 3    [0.020638514310121536, -0.0015102694742381573,...
# 4    [0.0066839889623224735, -0.03194846957921982, ...
# ..                                                 ...
# 113  [-0.023059912025928497, -0.04290644824504852, ...
# 114  [0.006376004312187433, -0.022294005379080772, ...
# 115  [0.044175487011671066, -0.014457432553172112, ...
# 116  [0.040616922080516815, -0.012434421107172966, ...
# 117  [0.05855109170079231, 0.05108918622136116, -0....
#
# [118 rows x 3 columns]
