# %%
import json
import os
import pickle
import sys

import pandas as pd
import numpy as np

# Import the 'rag_tools' module from the 'agent' directory
current_dir = os.getcwd()
project_dir = os.path.dirname(current_dir)

# Add the 'agent' directory to the sys.path
other_dir = os.path.join(project_dir, 'agent')
sys.path.append(other_dir)

# confirm the 'agent' directory is in the sys.path
for p in sys.path:
    print(p)

from rag_tools import generate_vocabulary, generate_embeddings
# Out:
# /usr/local/lib/python311.zip
# /usr/local/lib/python3.11
# /usr/local/lib/python3.11/lib-dynload
#
# /usr/local/lib/python3.11/site-packages
# /workspaces/connection_solver/src/agent

# %%
with open("/openai/api_key.json") as f:
    config = json.load(f)


os.environ["OPENAI_API_KEY"] = config["key"]

# %%
pickle_fp = "word_list4.pkl"
words = ["rumble", "table", "pony", "sift", "roll", "bun", "tree", "twist", "salad", "clap", "comb", "peal", "dig", "braid", "root", "book"]

vocabulary = generate_vocabulary(words)


# for word, definitions in vocabulary.items():
#     print(f"\n\n{word}:")
#     for definition in definitions:
#         print(definition)

# Convert dictionary to DataFrame
rows = []
for word, definitions in vocabulary.items():
    for definition in definitions:
        rows.append({'word': word, 'definition': definition})

df = pd.DataFrame(rows)

# Generate embeddings
embeddings = generate_embeddings(df["definition"].tolist())
df["embedding"] = [np.array(v) for v in np.array(embeddings).tolist()]

# save the dataframe as a pickle file
df.to_pickle(pickle_fp)

df
# Out:
#        word                                         definition  \
# 0    rumble  noun: A low, continuous noise, often resemblin...
# 1    rumble  noun: A street fight or brawl, particularly am...
# 2    rumble  verb: To make a low, continuous noise, like th...
# 3    rumble  verb: To move with a deep, resonant sound, e.g...
# 4    rumble  verb: To discover or catch someone in the act,...
# ..      ...                                                ...
# 119    book  verb: To arrange for someone to have a seat on...
# 120    book  verb: To engage a performer or reserve a venue...
# 121    book  verb: To record charges against a person by th...
# 122    book  verb: To register a player’s infraction in a s...
# 123    book  adjective: Relating to or involved with books,...
#
#                                              embedding
# 0    [-0.018864480778574944, -0.022428620606660843,...
# 1    [-0.024665802717208862, 0.0013567329151555896,...
# 2    [0.0014831050066277385, -0.03210413083434105, ...
# 3    [0.028904534876346588, 0.0011942152632400393, ...
# 4    [0.016046617180109024, -0.003660085378214717, ...
# ..                                                 ...
# 119  [-0.023059912025928497, -0.04290644824504852, ...
# 120  [-0.026062875986099243, -0.025175850838422775,...
# 121  [0.029429540038108826, -0.03344488516449928, -...
# 122  [-0.010450097732245922, 0.011089899577200413, ...
# 123  [-0.03040875680744648, -0.022781210020184517, ...
#
# [124 rows x 3 columns]
