# %%
import json
import os
import pickle
import sys

import pandas as pd
import numpy as np

# Import the 'rag_tools' module from the 'agent' directory
current_dir = os.getcwd()
project_dir = os.path.dirname(current_dir)

# Add the 'agent' directory to the sys.path
other_dir = os.path.join(project_dir, 'agent')
sys.path.append(other_dir)

# confirm the 'agent' directory is in the sys.path
for p in sys.path:
    print(p)

from embedvec_tools import generate_vocabulary, generate_embeddings
# Out:
# /usr/local/lib/python311.zip
# /usr/local/lib/python3.11
# /usr/local/lib/python3.11/lib-dynload
#
# /usr/local/lib/python3.11/site-packages
# /workspaces/connection_solver/src/agent

# %%
with open("/openai/api_key.json") as f:
    config = json.load(f)


os.environ["OPENAI_API_KEY"] = config["key"]

# %%
pickle_fp = "word_list6.pkl"
words = ["grain", "drain", "total", "cube", "syrup", "shred", "signature", "sap", "jam", "tax", "powder", "rock", "empty", "groove", "tip", "exhaust"]

vocabulary = generate_vocabulary(words)


# for word, definitions in vocabulary.items():
#     print(f"\n\n{word}:")
#     for definition in definitions:
#         print(definition)

# Convert dictionary to DataFrame
rows = []
for word, definitions in vocabulary.items():
    for definition in definitions:
        rows.append({'word': word, 'definition': definition})

df = pd.DataFrame(rows)

# Generate embeddings
embeddings = generate_embeddings(df["definition"].tolist())
df["embedding"] = [np.array(v) for v in np.array(embeddings).tolist()]

# save the dataframe as a pickle file
df.to_pickle(pickle_fp)

df
# Out:
#         word                                         definition  \
# 0      grain  noun: A small, hard seed of a cereal plant, su...
# 1      grain  noun: A single small particle or piece, such a...
# 2      grain  noun: The texture or pattern of fibers in wood...
# 3      grain  noun: An individual element or component withi...
# 4      grain  noun: A unit of weight in the avoirdupois syst...
# ..       ...                                                ...
# 125  exhaust  noun: The fumes or gases emitted as a result o...
# 126  exhaust  verb: To drain of resources or strength; to we...
# 127  exhaust    verb: To deplete or use up a resource entirely.
# 128  exhaust  verb: To discuss or examine a subject thorough...
# 129  exhaust  verb: To let out or expel air or gas from a co...
#
#                                              embedding
# 0    [-0.012600858695805073, 0.012784576043486595, ...
# 1    [0.020823834463953972, -0.024603812023997307, ...
# 2    [-0.007330888416618109, -0.0005790892755612731...
# 3    [0.025177670642733574, 0.00015151509433053434,...
# 4    [0.01975935325026512, -0.03580138459801674, -0...
# ..                                                 ...
# 125  [0.047517772763967514, 0.01325772050768137, -0...
# 126  [0.0431949645280838, 0.005937760695815086, -0....
# 127  [0.01849375106394291, 0.023994900286197662, -0...
# 128  [0.026929767802357674, -0.02039170078933239, -...
# 129  [0.017868539318442345, 0.007378402631729841, -...
#
# [130 rows x 3 columns]
