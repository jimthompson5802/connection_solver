# %%
import json
import os
import pickle
import sys

import pandas as pd
import numpy as np

# Import the 'rag_tools' module from the 'agent' directory
current_dir = os.getcwd()
project_dir = os.path.dirname(current_dir)

# Add the 'agent' directory to the sys.path
other_dir = os.path.join(project_dir, 'agent')
sys.path.append(other_dir)

# confirm the 'agent' directory is in the sys.path
for p in sys.path:
    print(p)

from embedvec_tools import generate_vocabulary, generate_embeddings
# Out:
# /usr/local/lib/python311.zip
# /usr/local/lib/python3.11
# /usr/local/lib/python3.11/lib-dynload
#
# /usr/local/lib/python3.11/site-packages
# /workspaces/connection_solver/src/agent

# %%
with open("/openai/api_key.json") as f:
    config = json.load(f)


os.environ["OPENAI_API_KEY"] = config["key"]

# %%
pickle_fp = "word_list4.pkl"
words = ["rumble", "table", "pony", "sift", "roll", "bun", "tree", "twist", "salad", "clap", "comb", "peal", "dig", "braid", "root", "book"]

vocabulary = generate_vocabulary(words)


# for word, definitions in vocabulary.items():
#     print(f"\n\n{word}:")
#     for definition in definitions:
#         print(definition)

# Convert dictionary to DataFrame
rows = []
for word, definitions in vocabulary.items():
    for definition in definitions:
        rows.append({'word': word, 'definition': definition})

df = pd.DataFrame(rows)

# Generate embeddings
embeddings = generate_embeddings(df["definition"].tolist())
df["embedding"] = [np.array(v) for v in np.array(embeddings).tolist()]

# save the dataframe as a pickle file
df.to_pickle(pickle_fp)

df
# Out:
#        word                                         definition  \
# 0    rumble  noun: A continuous deep, resonant sound, like ...
# 1    rumble  noun: A street fight between gangs or groups, ...
# 2    rumble     verb: To make or cause a deep, resonant sound.
# 3    rumble  verb: To move with a low, rolling noise, like ...
# 4    rumble        verb: To engage in a street fight or brawl.
# ..      ...                                                ...
# 119    book  verb: To engage a performer or reserve a venue...
# 120    book  verb: To register someone or something officia...
# 121    book  verb: To record charges against someone, typic...
# 122    book  adjective: Relating to books or the publishing...
# 123    book  adjective: Characterized by being in written o...
#
#                                              embedding
# 0    [-0.002630955073982477, -0.04030559957027435, ...
# 1    [-0.02475934848189354, 0.01010006945580244, -0...
# 2    [0.031156042590737343, -0.027694258838891983, ...
# 3    [0.003511470975354314, -0.00400950713083148, -...
# 4    [-0.0174231119453907, 0.008614887483417988, -0...
# ..                                                 ...
# 119  [-0.02122899889945984, -0.02168935537338257, -...
# 120  [0.02743612416088581, -0.0008092860807664692, ...
# 121  [0.03558064252138138, -0.03498633950948715, -0...
# 122  [-0.007815330289304256, -0.04484675079584122, ...
# 123  [0.032148875296115875, -0.0017539322143420577,...
#
# [124 rows x 3 columns]
